# %%
import keras
from keras import layers
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train.shape, x_test.shape
dimension = x_train.shape[1]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
num_data = 1000
frac_train = 0.8
frac_test = 0.2
x_train = x_train[0:int(frac_train*num_data)]
x_test = x_test[0:int(frac_test*num_data)]

# %%
norm_factor = 255.
x_train = x_train.astype('float32')/norm_factor
x_test = x_test.astype('float32')/norm_factor
x_train = np.reshape(x_train, (len(x_train), dimension, dimension, 1))
x_test = np.reshape(x_test, (len(x_test), dimension, dimension, 1))

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc = 0.0, scale = 1.0, size = x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc = 0.0, scale = 1.0, size = x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 3
for i in range(n):
    fig, axes = plt.subplots(1, 2)
    fig.set_size_inches(5, 5)
    axes[0].set_title('True image')
    im0 = axes[0].imshow(x_test[i].reshape(dimension, dimension), cmap = 'Reds')
    axes[1].set_title('Noisy image')
    im1 = axes[1].imshow(x_test_noisy[i].reshape(dimension, dimension), cmap = 'Reds')

# %%
input_img = keras.Input(shape = (dimension, dimension, 1))

# %%
x = layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same')(input_img)
x = layers.MaxPooling2D(pool_size = (2, 2), padding = 'same')(x)
x = layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same')(x)
encoded = layers.MaxPooling2D(pool_size = (2, 2), padding = 'same')(x)

# %%
x = layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same')(encoded)
x = layers.UpSampling2D(size = (2, 2))(x)
x = layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same')(x)
x = layers.UpSampling2D(size = (2, 2))(x)
decoded = layers.Conv2D(filters = 1, kernel_size = (3, 3), activation = 'sigmoid', padding = 'same')(x)

# %%
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
validation_split = 0.8
history = autoencoder.fit(x_train_noisy, x_train, epochs = 100, batch_size = 20, shuffle = True, validation_split = validation_split)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 14s 114ms/step - loss: 0.5826 - val_loss: 0.5159
# Epoch 2/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4853 - val_loss: 0.4613
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4337 - val_loss: 0.4058
# Epoch 4/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3657 - val_loss: 0.3226
# Epoch 5/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2854 - val_loss: 0.2551
# Epoch 6/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2363 - val_loss: 0.2312
# Epoch 7/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2218 - val_loss: 0.2219
# Epoch 8/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2117 - val_loss: 0.2106
# Epoch 9/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1980 - val_loss: 0.1933
# Epoch 10/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1828 - val_loss: 0.1810
# Epoch 11/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1732 - val_loss: 0.1721
# Epoch 12/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1666 - val_loss: 0.1657
# Epoch 13/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1603 - val_loss: 0.1606
# Epoch 14/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1572 - val_loss: 0.1572
# Epoch 15/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1527 - val_loss: 0.1547
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1489 - val_loss: 0.1509
# Epoch 17/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1461 - val_loss: 0.1503
# Epoch 18/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1436 - val_loss: 0.1483
# Epoch 19/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1420 - val_loss: 0.1441
# Epoch 20/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1390 - val_loss: 0.1421
# Epoch 21/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1376 - val_loss: 0.1429
# Epoch 22/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1371 - val_loss: 0.1396
# Epoch 23/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1360 - val_loss: 0.1378
# Epoch 24/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1346 - val_loss: 0.1407
# Epoch 25/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1326 - val_loss: 0.1359
# Epoch 26/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1307 - val_loss: 0.1352
# Epoch 27/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1293 - val_loss: 0.1340
# Epoch 28/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1291 - val_loss: 0.1378
# Epoch 29/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1295 - val_loss: 0.1328
# Epoch 30/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1295 - val_loss: 0.1342
# Epoch 31/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1266 - val_loss: 0.1322
# Epoch 32/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1250 - val_loss: 0.1307
# Epoch 33/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1240 - val_loss: 0.1305
# Epoch 34/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1230 - val_loss: 0.1296
# Epoch 35/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1221 - val_loss: 0.1294
# Epoch 36/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1213 - val_loss: 0.1286
# Epoch 37/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1205 - val_loss: 0.1279
# Epoch 38/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1201 - val_loss: 0.1294
# Epoch 39/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1226 - val_loss: 0.1274
# Epoch 40/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1200 - val_loss: 0.1283
# Epoch 41/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1182 - val_loss: 0.1265
# Epoch 42/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1179 - val_loss: 0.1264
# Epoch 43/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1171 - val_loss: 0.1267
# Epoch 44/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1167 - val_loss: 0.1269
# Epoch 45/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1161 - val_loss: 0.1256
# Epoch 46/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1154 - val_loss: 0.1250
# Epoch 47/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1150 - val_loss: 0.1257
# Epoch 48/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1156 - val_loss: 0.1246
# Epoch 49/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1152 - val_loss: 0.1258
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1144 - val_loss: 0.1246
# Epoch 51/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1140 - val_loss: 0.1254
# Epoch 52/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1131 - val_loss: 0.1243
# Epoch 53/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1121 - val_loss: 0.1237
# Epoch 54/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1117 - val_loss: 0.1243
# Epoch 55/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1121 - val_loss: 0.1236
# Epoch 56/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1112 - val_loss: 0.1242
# Epoch 57/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1105 - val_loss: 0.1235
# Epoch 58/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1104 - val_loss: 0.1236
# Epoch 59/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1100 - val_loss: 0.1238
# Epoch 60/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1100 - val_loss: 0.1236
# Epoch 61/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1090 - val_loss: 0.1236
# Epoch 62/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1088 - val_loss: 0.1228
# Epoch 63/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1087 - val_loss: 0.1246
# Epoch 64/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1092 - val_loss: 0.1258
# Epoch 65/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1088 - val_loss: 0.1232
# Epoch 66/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1074 - val_loss: 0.1228
# Epoch 67/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1070 - val_loss: 0.1238
# Epoch 68/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1070 - val_loss: 0.1235
# Epoch 69/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1063 - val_loss: 0.1226
# Epoch 70/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1065 - val_loss: 0.1231
# Epoch 71/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1061 - val_loss: 0.1235
# Epoch 72/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1057 - val_loss: 0.1226
# Epoch 73/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1068 - val_loss: 0.1277
# Epoch 74/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1073 - val_loss: 0.1220
# Epoch 75/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1058 - val_loss: 0.1253
# Epoch 76/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1053 - val_loss: 0.1227
# Epoch 77/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1039 - val_loss: 0.1222
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1035 - val_loss: 0.1232
# Epoch 79/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1036 - val_loss: 0.1231
# Epoch 80/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1034 - val_loss: 0.1222
# Epoch 81/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1026 - val_loss: 0.1224
# Epoch 82/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1034 - val_loss: 0.1223
# Epoch 83/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1025 - val_loss: 0.1232
# Epoch 84/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1022 - val_loss: 0.1237
# Epoch 85/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1025 - val_loss: 0.1227
# Epoch 86/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1013 - val_loss: 0.1232
# Epoch 87/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1011 - val_loss: 0.1244
# Epoch 88/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1021 - val_loss: 0.1226
# Epoch 89/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1011 - val_loss: 0.1221
# Epoch 90/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1003 - val_loss: 0.1244
# Epoch 91/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1000 - val_loss: 0.1226
# Epoch 92/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1006 - val_loss: 0.1229
# Epoch 93/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0997 - val_loss: 0.1230
# Epoch 94/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0988 - val_loss: 0.1231
# Epoch 95/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0988 - val_loss: 0.1227
# Epoch 96/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0986 - val_loss: 0.1224
# Epoch 97/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0987 - val_loss: 0.1229
# Epoch 98/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0985 - val_loss: 0.1283
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0979 - val_loss: 0.1225
# Epoch 100/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0976 - val_loss: 0.1233

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
train_loss = history.history['loss']
train_val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(dpi = 100)
plt.plot(epochs, train_loss, label = 'Loss')
plt.plot(epochs, train_val_loss, 'o', label = 'Val loss')
plt.title('Training and validation metrics')
plt.legend()
plt.savefig('history.png')

# %%
all_denoised_images = autoencoder.predict(x_test_noisy)
# Out:
# 7/7 [==============================] - 0s 21ms/step

# %%
test_loss  = autoencoder.evaluate(x_test_noisy, x_test, batch_size = 20)
test_loss
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1220
# 0.12201675772666931

# %%
n = 3
for i in range(n):
    fig, axes = plt.subplots(1, 3)
    fig.set_size_inches(8, 2)
    axes[0].set_title('Noisy image')
    im0 = axes[0].imshow(x_test_noisy[i].reshape(dimension, dimension), cmap = 'Reds')
    axes[1].set_title('Target image')
    im1 = axes[1].imshow(x_test[i].reshape(dimension, dimension), cmap = 'Reds')
    axes[2].set_title('Denoised image')
    im2 = axes[2].imshow(all_denoised_images[i].reshape(dimension, dimension), cmap = 'Reds')
    plt.savefig(f'comparison-{i}.png')
